# %% [markdown]
# ### Name: Joel Baffoe
#
# ### Index Number: 10627688
#
# ### Class: FPEN (Resit)

# %%
# Import libraries

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Read and view csv file into code
df = pd.read_csv('data.csv')
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ## Task 1 - Dealing with Null values and Duplicates

# %%
# Checking for Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Checking for null values
df.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
# Finding the number of missing values in dataframe
df.isnull().sum().sum()
# Out:
# 10

# %%
# Count total number of rows with missing values
df.isna().any(axis=1).sum()
# Out:
# 10

# %% [markdown]
# - There are no duplicate values in the dataframe
# - There are 10 missing values in 10 distinct rows in the dataframe

# %%
# Deleting Null Values
df = df.dropna(how='any')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed acidity         1591 non-null   float64
#  2   volatile acidity      1591 non-null   float64
#  3   citric acid           1591 non-null   float64
#  4   residual sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free sulfur dioxide   1591 non-null   float64
#  7   total sulfur dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# - Approach chosen to address the presence of null values is to remove the rows containing them.
# - Since 10 rows are less than 1% of the total number of rows in the data, removing them from the data will not have a strong effect on the results of the analysis to be performed
# -

# %% [markdown]
# ## Task 2 - Staistical Inferences of Entire Data Set

# %%
# General Statistics of data
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
df.mean()
# Out:
# ID                      801.060968
# fixed acidity             8.320616
# volatile acidity          0.527681
# citric acid               0.271477
# residual sugar            2.540761
# chlorides                 0.087500
# free sulfur dioxide      15.861722
# total sulfur dioxide     46.498429
# density                   0.996747
# pH                        3.311358
# sulphates                 0.658611
# alcohol                  10.426053
# quality                   5.637964
# dtype: float64

# %%
# Number of wine samples greater than the average values of each column
x =  df > df.mean()
x.sum()
# Out:
# ID                      795
# fixed acidity           626
# volatile acidity        779
# citric acid             744
# residual sugar          435
# chlorides               471
# free sulfur dioxide     673
# total sulfur dioxide    620
# density                 796
# pH                      774
# sulphates               635
# alcohol                 681
# quality                 854
# dtype: int64

# %% [markdown]
# ## Statistical Inferences for Each Column

# %% [markdown]
# ### Fixed Acidity

# %%
# General Statistical metrics for fixed acidity column
f_a = df['fixed acidity']
f_a.describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
# Histogram of fixed acidity 
sns.histplot(df['fixed acidity'])
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
# Calculating the Mean fixed acidity
fa_mean = df['fixed acidity'].mean()
fa_mean
# Out:
# 8.32061596480201

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['fixed acidity'] > fa_mean
avg_compare.value_counts()
# Out:
# False    965
# True     626
# Name: fixed acidity, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Fixed Acidity content of Beverage stock(Average = {fa_mean})')
plt.legend(title="Fixed Acidity",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Volatile Acidity

# %%
# General Statistical metrics for volatile acidity column
v_a = df['volatile acidity']
v_a.describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
# Histogram of Volatile Acidity Values 
sns.histplot(df['volatile acidity'])
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %%
# Calculating the Mean Volatile acidity
va_mean = df['volatile acidity'].mean()
va_mean
# Out:
# 0.5276807039597737

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['volatile acidity'] > va_mean
avg_compare.value_counts()
# Out:
# False    812
# True     779
# Name: volatile acidity, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Volatile Acidity content of Beverage stock(Average = {va_mean})')
plt.legend(title="Volatile Acidity",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Citric Acid

# %%
# General Statistical metrics for citric acid column
c_a = df['citric acid']
c_a.describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
# Histogram of citric Values 
sns.histplot(df['citric acid'])
# Out:
# <Axes: xlabel='citric acid', ylabel='Count'>

# %%
# Calculating the Mean citric acid
ca_mean = df['citric acid'].mean()
ca_mean
# Out:
# 0.27147705845380266

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['citric acid'] > ca_mean
avg_compare.value_counts()
# Out:
# False    847
# True     744
# Name: citric acid, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Citric Acid content of Beverage stock(Average = {ca_mean})')
plt.legend(title="Citric Acid",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Residual Sugar

# %%
# General Statistical metrics for residual sugar column
ra = df['residual sugar']
ra.describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
# Histogram of residual sugar 
sns.histplot(df['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar', ylabel='Count'>

# %%
# Calculating the Mean residual sugar
ra_mean = df['residual sugar'].mean()
ra_mean
# Out:
# 2.5407605279698307

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['residual sugar'] > ra_mean
avg_compare.value_counts()
# Out:
# False    1156
# True      435
# Name: residual sugar, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Residual Sugar content of Beverage stock(Average = {ra_mean})')
plt.legend(title="Residual Sugar",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Chlorides

# %%
# General Statistical metrics for chlorides column
chl = df['chlorides']
chl.describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
# Histogram of chlorides 
sns.histplot(df['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
# Calculating the Mean chlorides
chl_mean = df['chlorides'].mean()
chl_mean
# Out:
# 0.08749968573224387

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['chlorides'] > chl_mean
avg_compare.value_counts()
# Out:
# False    1120
# True      471
# Name: chlorides, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Chlorides content of Beverage stock(Average = {chl_mean})')
plt.legend(title="Chlorides",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Free Sulfur Dioxide

# %%
# General Statistical metrics for free sulfur dioxide column
fsd = df['free sulfur dioxide']
fsd.describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
# Histogram of free sulfur dioxide 
sns.histplot(df['free sulfur dioxide'])
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Count'>

# %%
# Calculating the Mean free sulfur dioxide
fsd_mean = df['free sulfur dioxide'].mean()
fsd_mean
# Out:
# 15.861722187303583

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['free sulfur dioxide'] > fsd_mean
avg_compare.value_counts()
# Out:
# False    918
# True     673
# Name: free sulfur dioxide, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Free Sulfur Dioxide content of Beverage stock (Average = {fsd_mean})')
plt.legend(title="Free Sulfur Dioxide",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Total Sulfur Dioxide

# %%
# General Statistical metrics for total sulfur dioxide column
tsd = df['total sulfur dioxide']
tsd.describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
# Histogram of free sulfur dioxide 
sns.histplot(df['total sulfur dioxide'])
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
# Calculating the Mean free sulfur dioxide
tsd_mean = df['total sulfur dioxide'].mean()
tsd_mean
# Out:
# 46.49842866121936

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['total sulfur dioxide'] > tsd_mean
avg_compare.value_counts()
# Out:
# False    971
# True     620
# Name: total sulfur dioxide, dtype: int64

# %%
# Pie Chart showing amount of wine samples measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Total Sulfur Dioxide content of Beverage stock (Average = {tsd_mean})')
plt.legend(title="Total Sulfur Dioxide",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ###  Density

# %%
# General Statistical metrics for density column
density = df['density']
density.describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
# Histogram of free sulfur dioxide 
sns.histplot(df['density'])
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
# Calculating the Mean density
density_mean = df['density'].mean()
density_mean
# Out:
# 0.9967465304839724

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['density'] > density_mean
avg_compare.value_counts()
# Out:
# True     796
# False    795
# Name: density, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Density content of Beverage stock (Average = {density_mean})')
plt.legend(title="Density",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### pH

# %%
# General Statistical metrics for pH column
pH = df['pH']
pH.describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Histogram of ph 
sns.histplot(df['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
# Calculating the Mean pH
pH_mean = df['pH'].mean()
pH_mean
# Out:
# 3.3113576367064743

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['pH'] > pH_mean
avg_compare.value_counts()
# Out:
# False    817
# True     774
# Name: pH, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of pH content of Beverage stock (Average = {pH_mean})')
plt.legend(title="pH",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Sulphates

# %%
# General Statistical metrics for sulphates column
sulphates = df['sulphates']
sulphates.describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
# Histogram of free sulfur dioxide 
sns.histplot(df['sulphates'])
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
# Calculating the Mean sulphates
sulphates_mean = df['sulphates'].mean()
sulphates_mean
# Out:
# 0.6586109365179132

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['sulphates'] > sulphates_mean
avg_compare.value_counts()
# Out:
# False    956
# True     635
# Name: sulphates, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Sulphates content of Beverage stock (Average = {sulphates_mean})')
plt.legend(title="Sulphates",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Alcohol

# %%
# General Statistical metrics for alcohol column
alc = df['alcohol']
alc.describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
# Histogram of alcohol 
sns.histplot(df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
# Calculating the Mean alcohol
alc_mean = df['alcohol'].mean()
alc_mean
# Out:
# 10.42605279698303

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['alcohol'] > alc_mean
avg_compare.value_counts()
# Out:
# False    910
# True     681
# Name: alcohol, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Alcohol content of Beverage stock(Average = {alc_mean})')
plt.legend(title="Alcohol",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ### Quality

# %%
# General Statistical metrics for quality column
quality = df['quality']
quality.describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
# Histogram of quality 
sns.histplot(df['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
# Calculating the Mean quality
quality_mean = df['quality'].mean()
quality_mean
# Out:
# 5.637963544940289

# %%
#Checking for samples higher or lower than the average value
avg_compare = df['quality'] > quality_mean
avg_compare.value_counts()
# Out:
# True     854
# False    737
# Name: quality, dtype: int64

# %%
# Pie Chart showing amount of wine samples  measured against the average
plt.pie(avg_compare.value_counts(), 
labels=['Lower than Average', 'Higher Than Average'],
autopct='%1.1f%%')
plt.title(f'Pie Chart of Quality content of Beverage stock(Average = {quality_mean})')
plt.legend(title="Quality",
         loc="center left",
         bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ## Correlation Between Columns

# %% [markdown]
# ### Fixed Acidity against Quality

# %%
df.plot(x='fixed acidity', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='fixed acidity', ylabel='quality'>

# %%
corr = df['fixed acidity'].corr(df.quality)
corr
# Out:
# 0.1249578135963529

# %% [markdown]
# ### Volatile Acidity against Quality

# %%
corr = df['volatile acidity'].corr(df.quality)
corr
# Out:
# -0.3893796617323098

# %%
df.plot(x='volatile acidity', y = 'quality', kind='scatter')
# Out:
# <Axes: xlabel='volatile acidity', ylabel='quality'>

# %% [markdown]
# ### Citric Acid against Quality

# %%
print(df['citric acid'].corr(df.quality))
# Out:
# 0.22426276192635236

# %%
df.plot(x='citric acid', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='citric acid', ylabel='quality'>

# %% [markdown]
# ### Residual Sugar against Quality

# %%
corr = df['residual sugar'].corr(df.quality)
corr
# Out:
# 0.013377130517510294

# %%
df.plot(x='residual sugar', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='residual sugar', ylabel='quality'>

# %% [markdown]
# ### Chlorides against Quality

# %%
corr = df['chlorides'].corr(df.quality)
corr
# Out:
# -0.12903609159441423

# %%
df.plot(x='chlorides', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='chlorides', ylabel='quality'>

# %% [markdown]
# ### Free Sulfur Dioxide against Quality

# %%
corr = df['chlorides'].corr(df.quality)
corr
# Out:
# -0.12903609159441423

# %%
df.plot(x='chlorides', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='chlorides', ylabel='quality'>

# %% [markdown]
# ### Total Sulfur Dioxide against Quality

# %%
corr = df['total sulfur dioxide'].corr(df.quality)
corr
# Out:
# -0.18465138992796504

# %%
df.plot(x='total sulfur dioxide', y= 'quality', kind='scatter')
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='quality'>

# %% [markdown]
# ### Density against Quality

# %%
corr = df['density'].corr(df.quality)
corr
# Out:
# -0.17479406716726728

# %%
df.plot(x='density', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='density', ylabel='quality'>

# %% [markdown]
# ### pH against Quality

# %%
corr = df['pH'].corr(df.quality)
corr
# Out:
# -0.058077264943359595

# %%
df.plot(x='pH', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='pH', ylabel='quality'>

# %% [markdown]
# ### Sulphates against Quality

# %%
corr = df['sulphates'].corr(df.quality)
corr
# Out:
# 0.24987756025543978

# %%
df.plot(x='sulphates', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='sulphates', ylabel='quality'>

# %% [markdown]
# ### Alcohol against Quality

# %%
corr = df['alcohol'].corr(df.quality)
corr
# Out:
# 0.4754440924263707

# %%
df.plot(x='alcohol', y='quality', kind='scatter')
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>
